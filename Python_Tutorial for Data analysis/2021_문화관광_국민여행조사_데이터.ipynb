# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# !pip install pyreadstat
import pyreadstat

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 그래프 한글폰트 사용설정 in Colab

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %config InlineBackend.figure_format = 'retina'
# !apt -qq -y install fonts-nanum

fontpath = '/content/drive/My Drive/파이썬/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

## Test
plt.figure(figsize=(3,3))
plt.text(0.5, 0.5, '한글 폰트 테스트 성공!!!', size=15)
plt.show()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
tour = pd.read_csv('/content/drive/MyDrive/2021 문화관광/DataSet/2020국민여행조사_변수선택.csv')

# %%
tour.columns
# Out:
# Index(['ID', 'SA1_1', 'SA1_2', 'SA1_3', 'SA1_4', 'SA1_5', 'D_TRA1_1_SPOT',
#        'D_TRA1_1_Code', 'D_TRA1_2_SPOT', 'D_TRA1_2_Code',
#        ...
#        'A10A_8', 'A10A_9', 'A10A_10', 'A10A_11', 'A10A_12', 'A11', 'A12',
#        'BSEX', 'BAGE', 'SAGE'],
#       dtype='object', length=209)

# %%
tour.head()
# Out:
#                ID  SA1_1  SA1_2  SA1_3  SA1_4  ...  A11 A12 BSEX BAGE SAGE
# 0   11010530201_1      0      0      0      0  ...             2    6   63
# 1  11010530201_10      0      0      0      0  ...             1    6   66
# 2  11010530201_17      0      1      0      0  ...    4   4    2    1   17
# 3   11010530201_2      0      0      1      0  ...             1    4   48
# 4  11010530201_22      0      0      0      0  ...             2    5   57
#
# [5 rows x 209 columns]

# %%
col_t = tour.columns
col_t[col_t.str.endswith('Code')]
columns1 = col_t[col_t.str.endswith('SPOT')]
columns2 = col_t[col_t.str.endswith('Code')]

# %%
pd.melt(tour, id_vars = 'D_TRA1_1_SPOT', value_vars='D_TRA1_1_Code').drop('variable', axis=1)
# Out:
#       D_TRA1_1_SPOT     value
# 0
# 1
# 2             32010  32010900
# 3             24020  24020900
# 4
# ...             ...       ...
# 50705
# 50706
# 50707
# 50708
# 50709
#
# [50710 rows x 2 columns]

# %%
tour.iloc[:,6:26]
# Out:
#       D_TRA1_1_SPOT D_TRA1_1_Code  ... D_TRA1_10_SPOT D_TRA1_10_Code
# 0                                  ...
# 1                                  ...
# 2             32010      32010900  ...
# 3             24020      24020900  ...
# 4                                  ...
# ...             ...           ...  ...            ...            ...
# 50705                              ...
# 50706                              ...
# 50707                              ...
# 50708                              ...
# 50709                              ...
#
# [50710 rows x 20 columns]

# %%
for i in range(0,80):
  print(columns1[i])
# Out:
# D_TRA1_1_SPOT
# D_TRA1_2_SPOT
# D_TRA1_3_SPOT
# D_TRA1_4_SPOT
# D_TRA1_5_SPOT
# D_TRA1_6_SPOT
# D_TRA1_7_SPOT
# D_TRA1_8_SPOT
# D_TRA1_9_SPOT
# D_TRA1_10_SPOT
# D_TRA2_1_SPOT
# D_TRA2_2_SPOT
# D_TRA2_3_SPOT
# D_TRA2_4_SPOT
# D_TRA2_5_SPOT
# D_TRA2_6_SPOT
# D_TRA2_7_SPOT
# D_TRA2_8_SPOT
# D_TRA2_9_SPOT
# D_TRA2_10_SPOT
# D_TRA3_1_SPOT
# D_TRA3_2_SPOT
# D_TRA3_3_SPOT
# D_TRA3_4_SPOT
# D_TRA3_5_SPOT
# D_TRA3_6_SPOT
# D_TRA3_7_SPOT
# D_TRA3_8_SPOT
# D_TRA3_9_SPOT
# D_TRA3_10_SPOT
# D_TRA4_1_SPOT
# D_TRA4_2_SPOT
# D_TRA4_3_SPOT
# D_TRA4_4_SPOT
# D_TRA4_5_SPOT
# D_TRA4_6_SPOT
# D_TRA4_7_SPOT
# D_TRA4_8_SPOT
# D_TRA4_9_SPOT
# D_TRA4_10_SPOT
# D_TRA5_1_SPOT
# D_TRA5_2_SPOT
# D_TRA5_3_SPOT
# D_TRA5_4_SPOT
# D_TRA5_5_SPOT
# D_TRA5_6_SPOT
# D_TRA5_7_SPOT
# D_TRA5_8_SPOT
# D_TRA5_9_SPOT
# D_TRA5_10_SPOT
# D_TRA6_1_SPOT
# D_TRA6_2_SPOT
# D_TRA6_3_SPOT
# D_TRA6_4_SPOT
# D_TRA6_5_SPOT
# D_TRA6_6_SPOT
# D_TRA6_7_SPOT
# D_TRA6_8_SPOT
# D_TRA6_9_SPOT
# D_TRA6_10_SPOT
# D_TRA7_1_SPOT
# D_TRA7_2_SPOT
# ...

# %%
df['value'].value_counts()
# Out:
#      101420
# Name: value, dtype: int64

# %% [markdown]
# 지역 여행지 증감률 풍경 등등등
